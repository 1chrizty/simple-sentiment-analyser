# %% [markdown]
# <a href="https://colab.research.google.com/github/1chrizty/simple-sentiment-analyser/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
c = input('Enter a sentence: ')
score = sid.polarity_scores(c)
print(score)
# Out:
# Enter a sentence: atta boy
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
